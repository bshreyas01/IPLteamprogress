# %%
import pandas as pd
import numpy as np

# %%
ipl = pd.read_csv('ipl.csv',usecols=['season','winner','team1','team2'])
ipl
# Out:
#      season                        team1                        team2  \
# 0      2017          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1      2017               Mumbai Indians       Rising Pune Supergiant
# 2      2017                Gujarat Lions        Kolkata Knight Riders
# 3      2017       Rising Pune Supergiant              Kings XI Punjab
# 4      2017  Royal Challengers Bangalore             Delhi Daredevils
# ..      ...                          ...                          ...
# 631    2016             Delhi Daredevils  Royal Challengers Bangalore
# 632    2016                Gujarat Lions  Royal Challengers Bangalore
# 633    2016          Sunrisers Hyderabad        Kolkata Knight Riders
# 634    2016                Gujarat Lions          Sunrisers Hyderabad
# 635    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# ...

# %%
allteams=ipl['team1'].unique().tolist()

# %%
ipl1=ipl[ipl['team1']=='Royal Challengers Bangalore']

# %% [raw]
# ipl2=ipl[ipl['team1']=='Mumbai Indians']

# %%
ipl3=ipl[ipl['team2']=='Royal Challengers Bangalore']

# %% [raw]
# ipl4=ipl[ipl['team2']=='Mumbai Indians']

# %%
rcb=ipl1.append(ipl3)

# %% [raw]
# mi=ipl2.append(ipl4)

# %% [raw]
# mitotno=mi.shape[0]

# %% [raw]
# miwin=mi[mi['winner']=='Mumbai Indians']

# %%
rcbwin=rcb[rcb['winner']=='Royal Challengers Bangalore']

# %% [raw]
# miwinno=miwin.shape[0]

# %%
rcbtotno=rcb.shape[0]

# %%
rcbwinno=rcbwin.shape[0]

# %%
years=ipl.season.unique().tolist()

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
seasonwinrcb=rcbwin.groupby('season').count()

# %%
seasontotrcb=rcb.groupby('season').count()
seasongames=seasontotrcb['winner'].tolist()

# %%
rcbwinratio=seasonwinrcb['winner']/seasontotrcb['winner']

# %%
allteams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Gujarat Lions',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Deccan Chargers',
#  'Kochi Tuskers Kerala',
#  'Pune Warriors',
#  'Rising Pune Supergiants']

# %%
remteam=['Sunrisers Hyderabad','Gujarat Lions','Rising Pune Supergiant','Deccan Chargers','Kochi Tuskers Kerala',
 'Pune Warriors','Rising Pune Supergiants','Chennai Super Kings',
 'Rajasthan Royals']

for i in remteam:
    allteams.remove(i)
allteams
# Out:
# ['Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Kings XI Punjab']

# %%
appended_data = []
for teamname in allteams:
    ipl1=ipl[ipl['team1']==teamname]
    ipl3=ipl[ipl['team2']==teamname]
    teamm=ipl1.append(ipl3)
    teammwin=teamm[teamm['winner']==teamname]
    teammtotno=teamm.shape[0]
    teammwinno=teammwin.shape[0]
    seasonwinteamm=teammwin.groupby('season').count()
    seasontotteamm=teamm.groupby('season').count()
    seasongames=seasontotteamm['winner'].tolist()
    teammwinratio=seasonwinteamm['winner']/seasontotteamm['winner']
    appended_data.append(teammwinratio)

# %%
appended_data
# Out:
# [season
#  2008    0.500000
#  2009    0.384615
#  2010    0.687500
#  2011    0.625000
#  2012    0.588235
#  2013    0.684211
#  2014    0.466667
#  2015    0.625000
#  2016    0.500000
#  2017    0.705882
#  Name: winner, dtype: float64,
#  season
#  2008    0.285714
#  2009    0.562500
#  2010    0.500000
#  2011    0.625000
#  2012    0.533333
#  2013    0.562500
#  2014    0.357143
#  2015    0.571429
#  2016    0.562500
#  2017    0.230769
#  Name: winner, dtype: float64,
#  season
#  2008    0.461538
#  2009    0.230769
#  2010    0.500000
#  2011    0.533333
#  2012    0.705882
#  2013    0.375000
#  2014    0.687500
#  2015    0.538462
#  2016    0.533333
#  2017    0.562500
#  Name: winner, dtype: float64,
#  season
#  2008    0.500000
#  2009    0.666667
#  2010    0.500000
#  2011    0.307692
#  2012    0.611111
#  2013    0.187500
#  2014    0.142857
#  2015    0.384615
#  2016    0.500000
#  2017    0.428571
#  Name: winner, dtype: float64,
#  season
# ...

# %%
customlines=[]
for i,j in zip(np.arange(len(allteams)),allteams):
    customlines.append(plt.plot(appended_data[i]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

blue_patch = mpatches.Patch(color='blue', label='Mumbai Indians')
orange_patch = mpatches.Patch(color='orange', label='Royal Challengers Bangalore')
red_patch = mpatches.Patch(color='red', label='Delhi Daredevils')
green_patch = mpatches.Patch(color='green', label='Kolkata Knight Riders')
purple_patch=mpatches.Patch(color='purple', label='Kings XI Punjab')

plt.legend(handles=[blue_patch,red_patch,orange_patch,green_patch,purple_patch],loc=3,fontsize='xx-small')
plt.xlabel('Season')
plt.ylabel('Win Ratio')
# Out:
# Text(0, 0.5, 'Win Ratio')
